# %%
import csv
import os
import sys
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sim_squat_data.csv')
df.head()
# Out:
#    updown       UWB     vel_x     vel_y     vel_z   accel_x   accel_y  \
# 0       0  0.727506  0.177350 -0.328205  0.028334  1.393288 -0.584914
# 1       0  0.713920  1.067111 -1.059223 -0.093918 -1.668938  1.363910
# 2       0  0.711137  0.103737  0.146653 -0.269246  1.474631 -1.330103
# 3       0  0.696934  1.003873 -1.165912 -0.152303 -1.414797  0.558007
# 4       0  0.693321  0.157843 -0.438974 -0.138881  1.220595 -0.411876
#
#     accel_z    gyro_x    gyro_y    gyro_z
# 0 -0.271930  1.352210 -0.107686 -0.224894
# 1 -1.170885  0.651052  0.932174 -1.163177
# 2  0.937158 -1.853041  0.868557  0.364519
# 3 -0.016737  1.101578  1.203498 -1.371185
# 4 -0.375748 -0.756846  0.164688  0.084541

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(2,3, figsize=(15, 10))

sns.boxplot(x='updown', y='accel_x', data=df, ax=axes[0,0]).set_title('accel_x')
sns.boxplot(x='updown', y='accel_y', data=df, ax=axes[0,1]).set_title('accel_y')
sns.boxplot(x='updown', y='accel_z', data=df, ax=axes[0,2]).set_title('accel_z')
sns.boxplot(x='updown', y='gyro_x', data=df, ax=axes[1,0]).set_title('gyro_x')
sns.boxplot(x='updown', y='gyro_y', data=df, ax=axes[1,1]).set_title('gyro_y')
sns.boxplot(x='updown', y='gyro_z', data=df, ax=axes[1,2]).set_title('gyro_z')

plt.tight_layout()
plt.show()

# %%
df_0_150 = df.iloc[:150]

colums = ['UWB','accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

fig, axes = plt.subplots(2,4, figsize=(25, 15))

for i, col in enumerate(colums):
    ax = axes[i//4, i%4]
    ax.plot(df_0_150.index, df_0_150[col], marker='o', linestyle='-', color='blue')
    ax.set_title(col)

plt.tight_layout()
plt.show()
